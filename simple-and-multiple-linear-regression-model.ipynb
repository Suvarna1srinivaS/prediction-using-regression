# %% [markdown]
# <a href="https://www.kaggle.com/code/suvarnasrinivas/simple-and-multiple-linear-regression-model?scriptVersionId=115864167" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <font color = "#FF5F1F"> Machine learning:</font>
#   Machine Learning is a branch of Artificial Intelligence which focuses on the use of data and algorithms to imitate the way that humans learn, gradually incrreasing it's accuracy.
#
# Machine learning is broadly classified into three categories:
#
# <font color = "#FF5F1F">1.   Supervised Machine learning:</font>
#
# In Supervised ML, labeled datasets are used to train the algorithms to classify the data and to predict the outcomes accurately.
#       The models used in Supervised ML are:
#
#
#    *   Linear Regression
#    *   Logistic Regression
#    *   Naive-Bayes
#    *   Support Vector Machine
#    *   K Nearest Neighbors
#    *   Decision Tree
#    *   Random Forest
#
#
# <font color = "#FF5F1F">2.   Unsupervised Machine learning:</font>
#
# In Unsupervised ML, unlabeled dataseta are used. The Unsupervised ML algorithms analyze the datasets and divide them into clusters. This is also called as Dimension Reduction Technique.
#       The models used in Unsupervised ML are:
#
#
#   *   Clustering
#   *   PCA / LDA
#   *   MBA
#
#
#
# <font color = "#FF5F1F">3.   Reinforcement Machine learning:</font>
#
# Reinforcement machine learning is a machine learning model that is similar to supervised learning, but the algorithm isn’t trained using sample data. This model learns as it goes by using trial and error. A sequence of successful outcomes will be reinforced to develop the best recommendation or policy for a given problem.

# %% [markdown]
# ---
#
# <font color = "#FF5F1F"><center>SUPERVISED MACHINE LEARNING </center>
#
# ---

# %% [markdown]
# In this, based on the dependent variable we will supervise the data. The data is labeled, which means data contains both dependent and independent variable.
#
# Generally in Supervised ML,
#
# *   independent variable is represented by 'x'
# *   dependent variable is represented by 'y'
#
# In Supervised ML, the dependent variable should be continuous or categorical.
# Supervised ML models are again calssified into two types:
#
#   <font color = "#FF5F1F">1.   Regression Type:</font>
#
# When the dependent variable is of continuous type, we will go for regression type models.
#     <font color = "#FF5F1F">Regression models:</font>
#
#   *   Linear Regression
#   *   Decision Tree
#   *   Ensemble learning
#        * bagging
#        * boosting
#             * ADA boosting
#             * Gradient boosting
#             * XG boosting
#        * random forest
#   *   KNN
#   *   SVM
#
#
#  <font color = "#FF5F1F"> 2.   Classification type: </font>
#
# When the dependent variable is of categorical type, we will go for regression type models.
#
#
#  <font color = "#FF5F1F">Classification models:</font>
#
#  *   Logistic Regression
#  *   Naive Bayes
#  *   Decision Tree
#  *   Ensemble learning
#       * bagging
#       * boosting
#           * ADA boosting
#           * Gradient boosting
#           * XG boosting
#       * random forest
#
# *   KNN
# *   SVM

# %% [markdown]
# <font color = "#FF5F1F">1. Linear Regression Model:
# --------------------
#
# This is a supevised learning approach in which  dependent vraible should be continuous. It shows the relationship between independent and dependent variable.

# %% [markdown]
# <font color = "#FF5F1F">a.   Simple linear regression:  </font>
#
#
# This is a univariate linear regresion that assess the relation between dependent and independent variable.
# One independent variable and dependent variable are considered to analyse the dataset.
# The simple linear model is expressed using the following equation:
#     y = a + bx + e, where
#
#    *   a = intercept (distance of best fit line from x-axis where it touches the x-axis)
#    *   b = slope (angle made by the line)
#    *   e = residual or error (distance between the datapoint and the predicted line)

# %% [markdown]
# <font color = "#FF5F1F">Ordinary Least Square technique (OLS):
#
# This technique is used in linear regresson models to estimate the coefficients of linear equation.
# This technique tries to minimize the sum of squared residuals between the actaul and predicted values.
# It will draw multiple lines and shows the line which covers the maximum data points (distance from the data to the line should be less)
#
#
# *   Advantages of Ordinary Least Square technique:
#
#  1.   It works with numeric attributes
#  2.   Model learning time is fast
#  3.   Prediction is powerful if the dimension is high
#
# *   Disadvantages of Ordinary Least Square technique:
#
#  1.   For high dimensional data, model prone to overfitting
#  2.   Cannot perform variable selection
#  3.   Sensitive to outliers

# %% [markdown]
# <font color = "#FF5F1F">Assumptions for Linear Regression Model:
#
#
# *   Before model building:
#
#  1.   Y must be normally distributed
#  2.   There must be a linear relationship between x and y
#
#
# *   After model building:
#
#  3.   There should not be multicollinearity in the data
#  4.   There should not be heteroscedasticity
#  5.   There should not be auto correlation in the data
#  6.   Residuals should also be normally distributed

# %% [markdown]
# <font color = "#FF5F1F">Evaluation:
#
#
# Once the optimized algorithm builds the model, it is crucial to assess the quality or performance of its statistical modeling.
# The evaluation of the model must be done on a new data set with labels that were not part of the optimization process
#
# Measures:
#
# The central quality measure for regression is root mean square erroe (RMSE)
# It measures the residuals (e) and penalizes large errors stronger than good predictions.
#
#
# Error measures can be measured and accumulated in various ways:
# *   Absolute score:
#   1.   Mean Square error (quadratic)
#   2.   Root Mean Square error (quadratic)
#   3.   Mean Absolute error (linear)
#
# *   Relative score error:
#   1. Mean Absolute Percentage error (linear)
#   2. R-square (co-efficient of determination)
#
#
#
# where,
# linear - equal weighting to errors
# quadratic - stronger penalty for larger errors
#
# Note: All measures have a range (0, infinity)
#
# R-square:
#
#
#                            sum of squares of residuals
#             R-square = 1 - ---------------------------
#                               total sum of squares
#
#
#   if R-square < 0, model performs bad
#   if R-square = 1, model performs perfectly
#
#   *   Range of R-square (-infinity, 1)
#   *   for a real world noisy datasets, R-square values above 0.4 are often considered okay
#   *   for a good model, R-square and adjacent R-square should be very close.
#
#
# The major difference between R-square and adj R-square is "The R-square of a model increases if we add another independent variable to the model. But the adj R-square value increases only if the added independent variable has any effect on dependent variable".

# %% [markdown]
# ***Let us go through an example to analyse the data and predict the dependent variable:***

# %%
import pandas as pd
car_df = pd.read_csv('/kaggle/input/regression-data/regression data.csv')

# %%
car_df.sample(2)
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 1         Mazda RX4 Wag  21.0    6  160.0  110   3.9  2.875  17.02   0   1
# 15  Lincoln Continental  10.4    8  460.0  215   3.0  5.424  17.82   0   0
#
#     gear  carb
# 1      4     4
# 15     3     4

# %% [markdown]
# <font color = "0096FF">knowing the structure of data:

# %%
print(car_df.columns)
print("shape of the dataset: ",car_df.shape)
print("size of the dataset: ",car_df.size)
# Out:
# Index(['Unnamed: 0', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')
# shape of the dataset:  (32, 12)
# size of the dataset:  384

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   mpg         32 non-null     float64
#  2   cyl         32 non-null     int64
#  3   disp        32 non-null     float64
#  4   hp          32 non-null     int64
#  5   drat        32 non-null     float64
#  6   wt          32 non-null     float64
#  7   qsec        32 non-null     float64
#  8   vs          32 non-null     int64
#  9   am          32 non-null     int64
#  10  gear        32 non-null     int64
#  11  carb        32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
car_df.describe().T
# Out:
#       count        mean         std     min        25%      50%     75%  \
# mpg    32.0   20.090625    6.026948  10.400   15.42500   19.200   22.80
# cyl    32.0    6.187500    1.785922   4.000    4.00000    6.000    8.00
# disp   32.0  230.721875  123.938694  71.100  120.82500  196.300  326.00
# hp     32.0  146.687500   68.562868  52.000   96.50000  123.000  180.00
# drat   32.0    3.596563    0.534679   2.760    3.08000    3.695    3.92
# wt     32.0    3.217250    0.978457   1.513    2.58125    3.325    3.61
# qsec   32.0   17.848750    1.786943  14.500   16.89250   17.710   18.90
# vs     32.0    0.437500    0.504016   0.000    0.00000    0.000    1.00
# am     32.0    0.406250    0.498991   0.000    0.00000    0.000    1.00
# gear   32.0    3.687500    0.737804   3.000    3.00000    4.000    4.00
# carb   32.0    2.812500    1.615200   1.000    2.00000    2.000    4.00
#
#           max
# mpg    33.900
# cyl     8.000
# disp  472.000
# hp    335.000
# drat    4.930
# ...

# %%
car_df = car_df.drop(["Unnamed: 0"], axis = 1)

# %%
car_df.isnull().sum()
# Out:
# mpg     0
# cyl     0
# disp    0
# hp      0
# drat    0
# wt      0
# qsec    0
# vs      0
# am      0
# gear    0
# carb    0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(car_df)
scaled_df = pd.DataFrame(scaled_data, columns = car_df.columns)
scaled_df.sample(2)
# Out:
#          mpg  cyl      disp        hp      drat        wt      qsec   vs   am  \
# 29  0.395745  0.5  0.184335  0.434629  0.396313  0.321401  0.119048  0.0  1.0
# 4   0.353191  1.0  0.720629  0.434629  0.179724  0.492713  0.300000  0.0  0.0
#
#     gear      carb
# 29   1.0  0.714286
# 4    0.0  0.142857

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (15,7))
sns.heatmap(scaled_df.corr(), annot = True, cmap = "viridis")
# Out:
# <AxesSubplot:>

# %%
main_df = scaled_df[['cyl', 'disp', 'hp', 'wt', 'carb', 'mpg']]

# %%
import numpy as np
from sklearn.model_selection import train_test_split


y = np.array(car_df["mpg"])
x = np.array(main_df["wt"]).reshape((-1,1))


x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3, random_state = 200)

# %%
from sklearn.linear_model  import LinearRegression

model = LinearRegression()

z = model.fit(x_train,y_train) 
intercept = z.intercept_
coefficient = z.coef_
print("intercept: ",intercept)
print("coefficient: ",coefficient)
# Out:
# intercept:  29.77080121973726
# coefficient:  [-20.9119378]

# %% [markdown]
# ### <font color = "0096FF">R-Square value for train data:

# %%
r_sqr_i_train = z.score(x_train, y_train)
print(r_sqr_i_train)
# Out:
# 0.8160056906119559

# %% [markdown]
# ### <font color = "0096FF">R-Square value for test data:

# %%
r_sqr_i_test = z.score(x_test, y_test)
print(r_sqr_i_test)
# Out:
# 0.495146407045431

# %% [markdown]
# ### <font color = "0096FF"> predicting values & calculating errors using train data:

# %%
predicted_train_y = z.predict(x_train)

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

MSE = mean_squared_error(y_train, predicted_train_y)
MAE = mean_absolute_error(y_train, predicted_train_y)
RMSE = mean_squared_error(y_train, predicted_train_y, squared = False)

print("mean square error: ", MSE)
print("mean absolute error: ", MAE)
print("root mean square error: ", RMSE)
# Out:
# mean square error:  7.032874551997231
# mean absolute error:  2.0730177730363515
# root mean square error:  2.6519567402198003

# %% [markdown]
# ### <font color = "0096FF"> predicting values & calculating errors using test data:

# %%
predicted_test_y = z.predict(x_test)

MSE = mean_squared_error(y_test, predicted_test_y)
MAE = mean_absolute_error(y_test, predicted_test_y)
RMSE = mean_squared_error(y_test, predicted_test_y, squared = False)

print("mean square error: ", MSE)
print("mean absolute error: ", MAE)
print("root mean square error: ", RMSE)
# Out:
# mean square error:  13.390938640964169
# mean absolute error:  3.222868805551113
# root mean square error:  3.659363146910152

# %% [markdown]
# **Linear Equation:**
#
#  y = 29.77080121973726 -20.9119378(x)

# %% [markdown]
# <font color = "#FF5F1F">b.   Multiple Linear Regression:
#
#
# Multiple linear regression is similar to the simple linear regression with the exception that multiple independent variables are used in the model to assess one dependent variable.
# The Multiple linear model is expressed using the following equation:
#     y = a + b1x1 + b2x2 + b3x3 + e, where
#
#    *   a = intercept (distance of best fit line from x-axis where it touches the x-axis)
#    *   b1, b2, b3 = slopes (angles made by the line)
#    *   e = residual or error (distance between the datapoint and the predicted line)

# %% [markdown]
# <font color = "#FF5F1F"> Assumptions of Multiple Linear Regression:</font>
# Assumptions are same as Linear Regression Model, But along with them:
# 1.   Non-collinearity
# 2.   Residuals must be normally distributed

# %%
y = np.array(car_df["mpg"])
X = np.array(main_df[["wt", "cyl"]]).reshape((-1,2))     #considering cyl column along with wt column for multiple linear regression


X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 200)
print("the shape of the new data frames are  - {} {} ".format(x_train.shape, x_test.shape))
# Out:
# the shape of the new data frames are  - (22, 1) (10, 1)

# %%
model_x = LinearRegression()
model_ii = model_x.fit(X_train,y_train)
intercept = model_ii.intercept_
coefficient = model_ii.coef_
print("intercept: ",intercept)
print("coefficient: ",coefficient)
# Out:
# intercept:  29.54369417056603
# coefficient:  [-14.15337162  -5.20085699]

# %% [markdown]
# ### <font color = "0096FF">R-Square value for train data:

# %%
r_sqr_ii_train  = model_ii.score(X_train, y_train)
print(r_sqr_ii_train)
# Out:
# 0.8696706635091289

# %% [markdown]
# ### <font color = "0096FF">R-Square value for test data:

# %%
r_sqr_ii_test  = model_ii.score(X_test, y_test)
print(r_sqr_ii_test)
# Out:
# 0.6607823399447199

# %% [markdown]
# ### <font color = "0096FF"> predicting values & calculating errors using train data:

# %%
predict_train_y = model_ii.predict(X_train)

MSE = mean_squared_error(y_train, predict_train_y)
MAE = mean_absolute_error(y_train, predict_train_y)
RMSE = mean_squared_error(y_train, predict_train_y, squared = False)

print("mean square error: ", MSE)
print("mean absolute error: ", MAE)
print("root mean square error: ", RMSE)
# Out:
# mean square error:  4.981620774217768
# mean absolute error:  1.8074063164074525
# root mean square error:  2.2319544740468538

# %% [markdown]
# ### <font color = "0096FF"> predicting values & calculating errors using test data:

# %%
predict_test_y = model_ii.predict(X_test)

MSE = mean_squared_error(y_test, predict_test_y)
MAE = mean_absolute_error(y_test, predict_test_y)
RMSE = mean_squared_error(y_test, predict_test_y, squared = False)

print("mean square error: ", MSE)
print("mean absolute error: ", MAE)
print("root mean square error: ", RMSE)
# Out:
# mean square error:  8.99754490237027
# mean absolute error:  2.604193133480425
# root mean square error:  2.999590789152792

# %% [markdown]
# **Linear Equation:**
#
# y = 29.54369417056603 - 14.15337162(x) - 5.20085699(x)

# %%
y = np.array(car_df["mpg"])
X = np.array(main_df[["wt", "cyl","disp"]]).reshape((-1,3))    #considering disp column along with cyl and wt column for multiple linear regression


X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 200)

# %%
model_x = LinearRegression()
model_iii = model_x.fit(X_train,y_train)
intercept = model_iii.intercept_
coefficient = model_iii.coef_
print("intercept: ",intercept)
print("coefficient: ",coefficient)
# Out:
# intercept:  29.80871074318749
# coefficient:  [-16.83419063  -6.82724381   4.53794294]

# %% [markdown]
# ### <font color = "0096FF">R-Square value for train data:

# %%
r_sqr_iii_train  = model_iii.score(X_train, y_train)
print(r_sqr_iii_train)
# Out:
# 0.8756927270193404

# %% [markdown]
# ### <font color = "0096FF">R-Square value for test data:

# %%
r_sqr_iii_test  = model_iii.score(X_test, y_test)
print(r_sqr_iii_test)
# Out:
# 0.6469604130499917

# %% [markdown]
# ### <font color = "0096FF"> predicting values & calculating errors using train data:

# %%
predict_train_y3 = model_iii.predict(X_train)

MSE = mean_squared_error(y_train, predict_train_y3)
MAE = mean_absolute_error(y_train, predict_train_y3)
RMSE = mean_squared_error(y_train, predict_train_y3, squared = False)

print("mean square error: ", MSE)
print("mean absolute error: ", MAE)
print("root mean square error: ", RMSE)
# Out:
# mean square error:  4.751437474786716
# mean absolute error:  1.7000718417998177
# root mean square error:  2.1797792261572537

# %% [markdown]
# ### <font color = "0096FF"> predicting values & calculating errors using test data:

# %%
predict_test_y3 = model_iii.predict(X_test)

MSE = mean_squared_error(y_test, predict_test_y3)
MAE = mean_absolute_error(y_test, predict_test_y3)
RMSE = mean_squared_error(y_test, predict_test_y3, squared = False)

print("mean square error: ", MSE)
print("mean absolute error: ", MAE)
print("root mean square error: ", RMSE)
# Out:
# mean square error:  9.364163220096799
# mean absolute error:  2.593514900852287
# root mean square error:  3.060092028043732

# %% [markdown]
# Linear Equation:
#
# y = 29.80871074318749 - 16.83419063(x) - 6.82724381(x) + 4.53794294(x)

# %% [markdown]
# **when i took two predict variables, r^2 value is more and RMSE value is less when compared to the model which has only one predict variable
# In the same manner, when i took three predict variables, r^2 value is more and RMSE value is less when compared to the model which has two predict variables
# from this i conclude that if the number of predict variables increases, r^2 value increases and the RMSE value decreases, i.e., the accuracy of the model increases**

# %% [markdown]
# <font color = "#FF5F1F"> Overfitting and Underfitting:
#
# * if the train error is high and test error is low, model is underfitted
# * if the train error is low and test error is high, model is overfitted (model not able to generalise the data)
# * if the train error and test error are close to each other, model is optimal
# * if the model has high variance, model is overfitted
# * if the model has high bias, model is underfitted
# * if the bias and variance are low, model is optimal. This is also called as bias-variance trade-off.

# %% [markdown]
# **From the RMSE values of train and test data, I conclude that the test error is high when compared to train error for all the three models I built. Hence, the model is overfitted.**

# %% [markdown]
# <font color = "#FF5F1F"> Types of tests in Statistics:
# * Parametric test: (assumptions and data distribution matters)
#     examples:
#     1. Linear Regressiom
#     2. Logistic regression
#
# * Non parametric test: (assumptions and data distribution doesn't matters)
#   examples:
#   1. Decision Tree
#   2. Ensemble Learning
#   3. K Nearest Neighbors
#   4. Support Vector Machine
